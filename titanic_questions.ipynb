# %%
import matplotlib.pyplot as plt 
import pandas as pd 

df = pd.read_csv("titanic.csv")

# %%
df.groupby(['Pclass'])['Survived'].sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
survived = df.groupby(['PassengerId'])['Survived'].sum()


survived.plot(kind='pie')
# Out:
# <Axes: ylabel='Survived'>
