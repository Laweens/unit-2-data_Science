# %% [markdown]
# # File Operations
# In this excercise you will begin working on using the `open` function within python to manipulate files and create reports on those files.
#
# **YOU ARE TO INCLUDE COMMENTS ALONG SIDE YOUR CODE**

# %% [markdown]
# 1. Open the file "states.txt" that you downloaded, what does this file contain?
# ```
#
# ```

# %% [markdown]
# *Use the code block below to open the same file, using a `for` loop print each line to the console.*

# %%
myFile = open("states.txt") #opening the file 

for x in myFile: ##PRINTING FOR EACH ITEM IN THE FILE 
    print(x)

# %% [markdown]
# 2. What type of chart would be best to represent this data? Explain why
# ```
# bar graph because it can show the distribution of all 50 states
# ```
# 3. How would we need to transform the data we have, to be displayed in this chart?
# ```
# a bar graph because it can show how many times a state was print
# ```

# %% [markdown]
# Using your knowledge of Python and Matplotlib write your code to transform and graph the data below.
#
# After your code create a new Markdown block to describe your analysis

# %%
import matplotlib.pyplot as plt 
myFile = open("states.txt")

#WE GAVE EACH STATE A VARIABLE OF 0 SO WE CAN KEEP COUNT INDIVIDUALLY OF HOW MANY TIMES THEY WERE PRINTED   
AL = 0
AK = 0
AZ = 0
AR = 0
CA = 0
CO = 0
CT = 0
DE = 0
FL = 0
GA = 0
HI = 0
ID = 0
IL = 0
IN = 0
IA = 0
KS = 0
KY = 0
LA = 0
ME = 0
MD = 0
MA = 0
MI = 0
MN = 0
MS = 0
MO = 0
MT = 0
NE = 0 
NV = 0
NH = 0
NJ = 0
NM = 0
NY = 0
NC = 0
ND = 0
OH = 0
OK = 0
OR = 0
PA = 0
RI = 0
SC = 0
SD = 0
TN = 0
TX = 0
UT = 0
VT = 0
VA = 0 
WA = 0
WV = 0
WI = 0
WY = 0

#FOR EVERY ITEM IN THE LIST "myFile" WE GO THROUGH IT AND ADD 1 DEPENDING ON WHICH STATE IT IS 
for i in myFile:
    i = i.strip()
    if i == "AL":
        AL += 1
    elif i =="AK":
        AK += 1
    elif i == "AZ":
        AZ += 1
    elif i =="AR":
        AR += 1
    elif i =="CA":
        CA += 1
    elif i =="CO":
            CO += 1
    elif i =="CT":
        CT += 1
    elif i =="DE":
        DE += 1
    elif i =="FL":
        FL += 1
    elif i =="GA":
        GA += 1
    elif i =="HI":
        HI += 1
    elif i =="ID":
        ID += 1
    elif i =="IL":
        IL += 1
    elif i =="IN":
        IN += 1
    elif i =="IA":
        IA += 1
    elif i =="KS":
        KS += 1
    elif i =="KY":
        KY += 1
    elif i =="LA":
        LA += 1
    elif i =="ME":
        ME += 1
    elif i =="MD":
        MD += 1
    elif i =="MA":
        MA += 1
    elif i =="MI":
        MI += 1
    elif i =="MN":
        MN += 1
    elif i =="MS":
        MS += 1
    elif i =="MO":
        MO += 1
    elif i =="MT":
        MT += 1
    elif i =="NE":
        NE += 1
    elif i =="NV":
        NV += 1
    elif i =="NH":
        NH += 1
    elif i =="NJ":
        NJ += 1
    elif i =="NM":
        NM += 1
    elif i =="NY":
        NY += 1
    elif i =="NC":
        NC += 1
    elif i =="ND":
        ND += 1
    elif i =="OH":
        OH += 1
    elif i =="OK":
        OK += 1
    elif i =="OR":
        OR += 1
    elif i =="PA":
        PA += 1
    elif i =="RI":
        RI += 1
    elif i =="SC":
        SC += 1
    elif i =="SD":
        SD += 1
    elif i =="TN":
        TN += 1
    elif i =="TX":
        TX += 1
    elif i =="UT":
        UT += 1
    elif i =="VT":
        VT += 1
    elif i =="VA":
        VA += 1
    elif i =="WA":
        WA += 1
    elif i =="WV":
        WV += 1
    elif i =="WI":
        WI += 1
    elif i =="WY":
        WY += 1
   
y = [AL,AK,AZ,AR,CA,CO,CT,DE,FL,GA,HI,ID,IL,IN,IA,KS,KY,LA,ME,MD,MA,MI,MN,MS,MO,
MT,NE,NV,NH,NJ,NM,NY,NC,ND,OH,OK,OR,PA,RI,SC,SD,TN,TX,UT,VT,VA,WA,WV,WI,WY] 

x = ["AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO",
"MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"] #string list for X
 #Int list for Y to plot 
#values are assigned based on the index number so A is equal to 2 
plt.figure(figsize=(50,50)) #used figsize to make our bar graph bigger so we can read it 
plt.ylabel("Times printed", fontsize = 25 ) #increased the font size
plt.xlabel("States", fontsize = 25 )
plt.title("Times states printed ")
plt.bar(x,y,label = "states") #labeling X and Y 
 #making it so the user can see the bars
# Out:
# <BarContainer object of 50 artists>

# %% [markdown]
# First we import madplotlib as plt and open the file states.txt to get started. I mad a new variable for each indidiual state so we can keep a counter seperately, leading me to have 50 variables overall. Having only 1 variable to keep count of all would be a problem because it would just group all the states together which isn't what we want. Then i have to use a for loop to go through each item in states.txt. For each count  of a state we add 1 to their specific variable then plot it all on our bar graph. we have to use figsize to make the graph bigger because 50 states and labels makes it very difficult to read at the default size.
